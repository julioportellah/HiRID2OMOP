# %% [markdown]
# # HiRID conversion to OMOP CDM v6

# %%
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy 
import re
import time
import datetime
import psycopg2

# %%
class UploadDB_Optimized:
    """
    Functionality: In this class you can translate the whole hiRID into Postgresql, feel free to modify it according to your needs\n
    Variables:\n
    \t*hirid_directory: Folder where your HiRID files uncompressed are located. Do not modify the file tree in order to work properly\n
    \t*postgres_add: Connection string for the postgres database\n
    \t*mapping_file: Directory path and file name for the Usagi's mapping folder, for more information about it check:\nhttps://www.ohdsi.org/web/wiki/doku.php?id=documentation:software:usagi\n 
    \t*max_group: Default value 250. Given that HiRID is divided in 250 groups the max group is the number of groups you want to upload\n
    \t*sampling_mode: Allows the user to insert only a percentage of the data\n
    Example:\t
    \tuploadDb=UploadDB_Optimized('D:\\YourFolderGoesHere\\',"dbname='dbname' user='user' host='localhost' password='password' connect_timeout=1",'D:\\DirectoryPath\\Vocabulary_translation.csv',1)\n
    \tuploadDb.translate_upload()
    """
    def __init__(self, hirid_directory, postgres_add, mapping_file,  max_group=250, sampling_mode=False):
        #Simple variables
        self.hirid_directory = hirid_directory
        self.postgres_add = postgres_add
        if(max_group>250):
            max_group=250
        elif(max_group<1):
            max_group=1
        self.max_group = max_group
        self.person_upload_time=0
        self.sampling_mode=sampling_mode
        #Arrays &  Dictionaries
        self.groups=np.arange(0,self.max_group)
        self.pharma_lengths=np.array([])
        self.measure_lengths=np.array([])
        self.obs_period_lengths=np.array([])
        self.visit_lengths=np.array([])
        self.obs_lengths=np.array([])
        #Dataframes
        self.source_2_map=pd.read_csv(mapping_file, sep=',')
        self.variableid_dict=self.source_2_map.set_index('source_code')['target_concept_id'].to_dict()
        self.person_df=pd.DataFrame()
        self.observations_df=pd.DataFrame()
        self.pharmaceutic_df=pd.DataFrame()
        self.person_visit_dict={}
        #Statistics
        self.local_initial_rows_obs=0
        self.local_final_rows_obs=0
        self.local_inital_rows_phr=0
        self.local_final_rows_phr=0
        self.global_initial_rows_obs=0
        self.global_final_rows_obs=0
        self.global_inital_rows_phr=0
        self.global_final_rows_phr=0
        pass
    
    
    def translate_upload(self):
        print('Beginning the translate and upload process...')
        begin_time=datetime.datetime.now()
        print('Process began at: '+str(begin_time))
        global_start = time.process_time()
        self.upload_person()
        if(self.sampling_mode):
            print('Translating in sample mode, expect less translated items')
            pass
        for i in self.groups:
            group_start = time.process_time()
            print('\tTranslating item '+str(i+1) + ' of 250')
            self.upload_observation_period(i)
            self.upload_visit_occurrence(i)
            self.upload_measurement(i)
            self.global_initial_rows_obs+=self.local_initial_rows_obs
            self.global_final_rows_obs+=self.local_final_rows_obs
            
            self.upload_pharmaceuticals(i)
            self.global_inital_rows_phr+=self.local_inital_rows_phr
            self.global_final_rows_phr+=self.local_final_rows_phr
            print('\tGroup #{:d} completed!'.format(i))
            pass
        end_time=datetime.datetime.now()
        final_time=(end_time-begin_time).total_seconds()
        print('Full Translation completed!')
        print('{:d} of {:d} ({:.2%}) total observations translated'.format(self.global_final_rows_obs,
                                                                               self.global_initial_rows_obs,
                                                                              float(self.global_final_rows_obs)/float(self.global_initial_rows_obs)))
        print('{:d} of {:d} ({:.2%}) drugs records translated'.format(self.global_final_rows_phr,
                                                                          self.global_inital_rows_phr,
                                                                         float(self.global_final_rows_phr)/float(self.global_inital_rows_phr)))
        total_initial=self.global_initial_rows_obs+self.global_inital_rows_phr
        total_final=self.global_final_rows_obs+self.global_final_rows_phr
        print('{:d} of {:d} ({:.2%}) all the records were translated'.format(total_final,
                                                                                 total_initial,
                                                                                 float(total_final)/float(total_initial)))
        print('Process ended at: '+str(datetime.datetime.now()))
        pass
    
    def convert_df2sql(self,dataframe,table_name):
        dataframe.to_csv(self.hirid_directory+table_name+'.csv',index=False)
        conn = psycopg2.connect(self.postgres_add)
        cur = conn.cursor()
        with open('D:\\MIMICIII\\HiRID\\'+table_name+'.csv', 'r') as f:
            # Notice that we don't need the `csv` module.
            next(f) # Skip the header row.
            cur.copy_from(f, table_name, sep=',',null='')

        conn.commit()
        conn.close()
        pass
    
    def transform_float(self,x):
        try:
            if (isinstance(x, str)):
                return float(re.findall(r'\d+', x)[0])
            else:
                return float(x)
        except Exception as e:
            print(e)
            print(x)
            return(np.nan)
        pass
    
    def transform_float_min(self,x):
        try:
            if (isinstance(x, str)):
                return float(re.findall(r'\d+', x)[0])
            else:
                return float(x)
        except Exception as e:
            print(e)
            print(x)
            return(np.nan)
        pass
    
    def upload_measurement(self,group_number):
        print('\t\tUploading measurements for group #{:d}'.format(group_number))
        obs2measurement=self.observations_df.copy()
        self.local_initial_rows_obs=obs2measurement.shape[0]
        obs2measurement['measurement_concept_id']=obs2measurement['variableid'].map(self.variableid_dict)
        obs2measurement[obs2measurement[['measurement_concept_id']].isnull().any(axis=1)][['variableid']].count().values
        obs2measurement.rename(columns={'patientid': 'person_id'})
        obs2measurement[obs2measurement[['measurement_concept_id']].isnull().any(axis=1)][['variableid']].drop_duplicates()
        obs2measurement=obs2measurement[obs2measurement.measurement_concept_id.notna()]
        obs2measurement['measurement_concept_id']=obs2measurement.measurement_concept_id.astype(int)
        obs2measurement['measurement_datetime']=pd.to_datetime(obs2measurement['datetime'], dayfirst=True)
        obs2measurement['measurement_date']=pd.to_datetime(obs2measurement['datetime']).dt.date
        obs2measurement['measurement_time']=pd.to_datetime(obs2measurement['datetime']).dt.time
        obs2measurement['measurement_type_concept_id']=42530833 #LOINC: Laboratory
        obs2measurement['value_as_number']=obs2measurement.value
        obs2measurement['unit_source_value']=obs2measurement.status
        obs2measurement['measurement_source_concept_id']=obs2measurement.type
        obs2measurement['value_source_value']=obs2measurement.value
        obs2measurement = obs2measurement[obs2measurement.stringvalue != '!folgt']
        obs2measurement = obs2measurement[obs2measurement.stringvalue != '!fehlt']
        obs2measurement = obs2measurement[obs2measurement.stringvalue != '!folgt mmol/L']
        obs2measurement = obs2measurement[obs2measurement.stringvalue != 'mmol/L']
        obs2measurement = obs2measurement[obs2measurement.stringvalue != '---']
        obs2measurement = obs2measurement[obs2measurement.stringvalue != 'N']
        obs2measurement['range_low'] = [self.transform_float_min(x.replace('<','')) if str(x).find('<') != -1 else np.nan for x in obs2measurement['stringvalue']]
        obs2measurement['range_high'] = [self.transform_float(x) if (str(x).find('<') != 0 and x is not np.nan) else np.nan for x in obs2measurement['stringvalue']]
        obs2measurement.value_as_concept_id=0
        obs2measurement.loc[obs2measurement['status']==1, 'value_as_concept_id'] = 45878591 #LOINC: out of range
        obs2measurement.loc[obs2measurement['status']==64, 'value_as_concept_id'] = 45880425 #LOINC: Greatly
        obs2measurement.loc[obs2measurement['status']==32, 'value_as_concept_id'] = 36309396 #LOINC: Not Measured 
        obs2measurement.person_id=obs2measurement.patientid
        obs2measurement['visit_occurrence_id']=obs2measurement['patientid'].map(self.person_visit_dict)
        #passing the data
        obs2measurement['person_id']=obs2measurement.patientid
        obs2measurement['measurement_id'] = np.arange(len(obs2measurement))+(self.measure_lengths.sum()+1) #np.arange(len(obs2measurement))+1
        self.measure_lengths=np.append(self.measure_lengths,self.observations_df.shape[0])
        obs2measurement['operator_concept_id'] = np.nan
        obs2measurement['unit_concept_id'] = np.nan
        obs2measurement['provider_id'] = np.nan
        obs2measurement['visit_detail_id'] = np.nan
        obs2measurement['measurement_source_value'] = obs2measurement.value_as_number
        obs2measurement['measurement_source_concept_id'] = obs2measurement.variableid
        obs2measurement['measurement_time'] = obs2measurement.measurement_time.astype(str)
        obs2measurement['measurement_time'] = obs2measurement['measurement_time'].str.slice(0,8)
        obs2measurement=obs2measurement[['measurement_id','person_id','measurement_concept_id','measurement_date',
                            'measurement_datetime','measurement_time','measurement_type_concept_id',
                           'operator_concept_id','value_as_number','value_as_concept_id','unit_concept_id',
                            'range_low','range_high','provider_id','visit_occurrence_id','visit_detail_id',
                            'measurement_source_value','measurement_source_concept_id','unit_source_value',
                            'value_source_value'
                           ]]
        obs2measurement['measurement_id']=obs2measurement['measurement_id'].astype(int)
        obs2measurement['person_id']=obs2measurement['person_id'].astype(int)
        obs2measurement['visit_occurrence_id']=obs2measurement['visit_occurrence_id'].astype(int)
        if(self.sampling_mode):
            obs2measurement=obs2measurement.sample(frac=0.1, replace=False)
            pass
            
        self.convert_df2sql(obs2measurement, 'measurement')
        self.local_final_rows_obs=obs2measurement.shape[0]
        
        print('\t\tMeasurement #{:d} done!'.format(group_number))
        print('\t\t{:d} of {:d} ({:.2%}) observations translated'.format(self.local_final_rows_obs,
                                                                         self.local_initial_rows_obs,
                                                               float(self.local_final_rows_obs)/float(self.local_initial_rows_obs)))
        pass
    
    
    def upload_pharmaceuticals(self, group_number):
        print('\t\tUploading visit pharmaceuticals for group #{:d}'.format(group_number))
        self.pharmaceutic_df=pd.read_csv(self.hirid_directory+'raw_stage\\pharma_records\\csv\\part-'+str(group_number)+'.csv')
        pharma_2_drug=self.pharmaceutic_df.copy()
        self.local_inital_rows_phr=pharma_2_drug.shape[0]
        pharma_2_drug['drug_exposure_id'] = np.arange(len(pharma_2_drug))+(self.pharma_lengths.sum()+1)
        self.pharma_lengths=np.append(self.pharma_lengths,self.pharmaceutic_df.shape[0])
        pharma_2_drug['person_id']=pharma_2_drug['patientid']
        pharma_2_drug['drug_exposure_start_datetime']=pd.to_datetime(pharma_2_drug['givenat'], dayfirst=True)
        pharma_2_drug['drug_exposure_start_date']=pd.to_datetime(pharma_2_drug['drug_exposure_start_datetime']).dt.date
        pharma_2_drug['drug_exposure_end_datetime']=pd.to_datetime(pharma_2_drug['enteredentryat'], dayfirst=True)
        pharma_2_drug['drug_exposure_end_datetime']=np.where(pharma_2_drug['drug_exposure_end_datetime']>pharma_2_drug['drug_exposure_start_datetime'],pharma_2_drug['drug_exposure_end_datetime'],pharma_2_drug['drug_exposure_start_datetime'])
        pharma_2_drug['drug_exposure_end_date']=pd.to_datetime(pharma_2_drug['drug_exposure_end_datetime']).dt.date
        pharma_2_drug['verbatim_end_date']=pd.to_datetime(pharma_2_drug['drug_exposure_end_datetime']).dt.date
        pharma_2_drug['drug_type_concept_id']=38000180
        pharma_2_drug['stop_reason']=0
        pharma_2_drug['visit_occurrence_id']=pharma_2_drug['patientid'].map(self.person_visit_dict)
        pharma_2_drug['quantity']=pharma_2_drug['givendose']
        pharma_2_drug['days_supply']=0
        pharma_2_drug['sig']=0
        pharma_2_drug['lot_number']=np.nan
        pharma_2_drug['provider_id']=np.nan
        pharma_2_drug['visit_detail_id']=np.nan
        pharma_2_drug['drug_source_value']=pharma_2_drug['pharmaid']
        pharma_2_drug['drug_source_concept_id']=pharma_2_drug['typeid']
        pharma_2_drug['route_source_value']=pharma_2_drug['route']
        pharma_2_drug['dose_unit_source_value']=pharma_2_drug['doseunit']
        pharma_2_drug['drug_concept_id']=pharma_2_drug['pharmaid'].map(self.variableid_dict)
        pharma_2_drug['route_concept_id']=0
        pharma_2_drug.loc[pharma_2_drug['route']=='iv-inf', 'route_concept_id'] = 45884925 #LOINC: Infusion
        pharma_2_drug.loc[pharma_2_drug['route']=='iv-inj', 'route_concept_id'] = 45877627 #LOINC: Injection Intravenous
        pharma_2_drug.loc[pharma_2_drug['route']=='SC-inj', 'route_concept_id'] = 45882083 #LOINC: Injection, subcutaneous
        pharma_2_drug.loc[pharma_2_drug['route']=='SC-inj', 'route_concept_id'] = 45882083 #LOINC: Injection, subcutaneous
        pharma_2_drug.loc[pharma_2_drug['route']=='inhal', 'route_concept_id'] = 45880877 #LOINC: Inhalation
        pharma_2_drug.loc[pharma_2_drug['route']=='ep-inj', 'route_concept_id'] = 45877638 #LOINC: Injection, epidural
        pharma_2_drug.loc[pharma_2_drug['route']=='transcutan', 'route_concept_id'] = 45877646 #LOINC: Transdermal
        pharma_2_drug.loc[pharma_2_drug['route']=='paravert', 'route_concept_id'] = 4170267 #LOINC: Paravertebral route
        pharma_2_drug['refills'] = pharma_2_drug.groupby(['route_concept_id', 'infusionid']).cumcount()
        pharma_2_drug = pharma_2_drug[pharma_2_drug['drug_concept_id'].notna()]
        pharma_2_drug=pharma_2_drug[['drug_exposure_id','person_id','drug_concept_id','drug_exposure_start_date',
                            'drug_exposure_start_datetime','drug_exposure_end_date','drug_exposure_end_datetime',
                           'verbatim_end_date','drug_type_concept_id','stop_reason','refills',
                            'quantity','days_supply','sig','route_concept_id','lot_number',
                            'provider_id','visit_occurrence_id','visit_detail_id',
                            'drug_source_value','drug_source_concept_id','route_source_value','dose_unit_source_value'
                           ]]
        pharma_2_drug['drug_exposure_id']=pharma_2_drug['drug_exposure_id'].astype(int)
        pharma_2_drug['person_id']=pharma_2_drug['person_id'].astype(int)
        pharma_2_drug['visit_occurrence_id']=pharma_2_drug['visit_occurrence_id'].astype(int)
        pharma_2_drug['drug_concept_id']=pharma_2_drug['drug_concept_id'].astype(float).astype(int)
        if(self.sampling_mode):
            pharma_2_drug=pharma_2_drug.sample(frac=0.1, replace=False)
            pass
        self.convert_df2sql(pharma_2_drug, 'drug_exposure')
        self.local_final_rows_phr=pharma_2_drug.shape[0]
        print('\t\tPharmaceuticals #{:d} done!'.format(group_number))
        print('\t\t{:d} of {:d} ({:.2%}) drugs records translated'.format(self.local_final_rows_phr,
                                                                          self.local_inital_rows_phr,
                                                                         float(self.local_final_rows_phr)/float(self.local_inital_rows_phr)))
        pass
    
    
    def upload_observation_period(self,group_number):
        print('\t\tUploading observational period for group #{:d}'.format(group_number))
        self.observations_df=pd.read_csv(self.hirid_directory+'raw_stage\\observation_tables\\csv\\part-'+str(group_number)+'.csv')
        obs_period=self.observations_df.copy()
        obs_period['visit_start_datetime']=obs_period.groupby(['patientid'])['datetime'].transform('min')
        obs_period['visit_end_datetime']=obs_period.groupby(['patientid'])['entertime'].transform('max')
        obs_period['observation_period_start_date']= pd.to_datetime(obs_period['visit_start_datetime']).dt.date
        obs_period['observation_period_end_date']= pd.to_datetime(obs_period['visit_end_datetime']).dt.date
        obs_period['period_type_concept_id']=44814724 # Obs Period Type: Period covering healthcare encounters
        obs_period = obs_period.rename(columns={'patientid': 'person_id'})
        obs_period['observation_period_id']=0
        obs_period=obs_period[['observation_period_id','person_id','observation_period_start_date',
                               'observation_period_end_date','period_type_concept_id']]
        obs_period=obs_period.drop_duplicates()
        obs_period['observation_period_id']= np.arange(len(obs_period))+(self.obs_period_lengths.sum()+1)
        obs_period['observation_period_id'] = obs_period['observation_period_id'].astype(int)
        self.obs_period_lengths=np.append(self.obs_period_lengths,obs_period.shape[0])
        self.convert_df2sql(obs_period, 'observation_period')
        print('\t\tObservational period #{:d} done!'.format(group_number))
        pass
    
    def upload_visit_occurrence(self, group_number):
        print('\t\tUploading visit occurrence for group #{:d}'.format(group_number))
        self.observasations_df=pd.read_csv(self.hirid_directory+'raw_stage\\observation_tables\\csv\\part-'+str(group_number)+'.csv')
        
        visit_obs=self.observations_df.copy()
        visit_obs['visit_start_datetime']=visit_obs.groupby(['patientid'])['datetime'].transform('min')
        visit_obs['visit_end_datetime']=visit_obs.groupby(['patientid'])['entertime'].transform('max')
        visit_obs['visit_start_date']= visit_obs['visit_start_datetime']
        visit_obs['visit_end_date']= visit_obs['visit_end_datetime']
        visit_obs['visit_type_concept_id']=32037 # Vocabulary Visit: Intensive Care
        visit_obs['provider_id']=np.nan
        visit_obs['care_site_id']=np.nan
        visit_obs['visit_source_value']=0
        visit_obs['visit_source_concept_id']=0
        visit_obs['admitted_from_concept_id']=32199 # Vocabulary Visit: Information not available
        visit_obs['discharge_to_concept_id']=0
        visit_obs['discharge_to_source_value']=0
        visit_obs=visit_obs.drop_duplicates()
        visit_obs = visit_obs.rename(columns={'patientid': 'person_id'})
        visit_obs['admitted_from_source_value']=0
        visit_obs['preceding_visit_occurrence_id']=np.nan
        visit_obs['visit_concept_id']=32037 # Vocabulary Visit: Intensive Care
        visit_obs['visit_occurrence_id'] = 0
        visit_obs=visit_obs[['visit_occurrence_id','person_id','visit_concept_id','visit_start_date',
                             'visit_start_datetime','visit_end_date','visit_end_datetime','visit_type_concept_id',
                            'provider_id','care_site_id','visit_source_value','visit_source_concept_id',
                            'admitted_from_concept_id','admitted_from_source_value','discharge_to_source_value',
                            'discharge_to_concept_id','preceding_visit_occurrence_id']]
        visit_obs=visit_obs.drop_duplicates()
        visit_obs['visit_occurrence_id'] = np.arange(len(visit_obs))+(self.visit_lengths.sum()+1)
        visit_obs['visit_occurrence_id'] = visit_obs['visit_occurrence_id'].astype(int)
        self.visit_lengths=np.append(self.visit_lengths,visit_obs.shape[0])
        self.convert_df2sql(visit_obs, 'visit_occurrence')
        self.person_visit_dict=visit_obs.set_index('person_id')['visit_occurrence_id'].to_dict()
        print('\t\tVisit occurrence #{:d} done!'.format(group_number))
        pass
    
    def upload_person(self,full_court=True):
        print('\tTranslating and uploading Person table')
        start = time.process_time()
        patient=pd.read_csv(self.hirid_directory+'general_table.csv')
        patient['person_id']=patient.patientid.astype(int)
        patient['gender_concept_id']=np.where(patient['sex']=='F', 8532 , 8507)
        patient['admission_date']=pd.to_datetime(patient['admissiontime'], dayfirst=True)
        patient['birth_datetime'] = patient['admission_date'] -  pd.to_timedelta(patient['age']*365, unit = 'D')
        patient['year_of_birth'] = pd.DatetimeIndex(patient['birth_datetime']).year
        patient['month_of_birth'] = pd.DatetimeIndex(patient['birth_datetime']).month
        patient['day_of_birth'] = pd.DatetimeIndex(patient['birth_datetime']).day
        patient['death_datetime'] = np.nan
        patient['race_concept_id']=0
        patient['ethnicity_concept_id']=0
        patient['location_id']=np.nan
        patient['provider_id']=np.nan
        patient['care_site_id']=np.nan
        patient['person_source_value']=patient.patientid.astype(int)
        patient['gender_source_value']=patient['sex']
        patient['gender_source_concept_id']=0
        patient['race_source_value']=np.nan
        patient['race_source_concept_id']=0
        patient['ethnicity_source_value']=np.nan
        patient['ethnicity_source_concept_id']=0
        patient=patient[['person_id','gender_concept_id','year_of_birth','month_of_birth','day_of_birth',
                         'birth_datetime','death_datetime','race_concept_id','ethnicity_concept_id',
                        'location_id','provider_id','care_site_id','person_source_value','gender_source_value',
                        'gender_source_concept_id','race_source_value','race_source_concept_id',
                        'ethnicity_source_value','ethnicity_source_concept_id']]
        self.convert_df2sql(patient, 'person')
        self.person_upload_time=time.process_time() - start
        self.person_df=patient.copy()
        print('\tPerson upload successful!')
        pass

# %%
uploadDb=UploadDB_Optimized('D:\\MIMICIII\\HiRID\\','postgresql://postgres:jp123456$@localhost:5432/omop_cdm3','D:\\MIMICIII\\HiRID\\Translation_13Aug.csv',250)
uploadDb.translate_upload()
# Out:
# Beginning the translate and upload process...
# Process began at: 2020-08-13 18:09:46.449215
# 		Translating and uploading Person table
# 		Person upload successful!
# 	Translating item 1 of 250
# 		Uploading observational period for group #0
# 		Observational period #0 done!
# 		Uploading visit occurrence for group #0
# 		Visit occurrence #0 done!
# 		Uploading measurements for group #0
# C:\Users\julio\Anaconda3\lib\site-packages\ipykernel_launcher.py:160: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# 		Measurement #0 done!
# 		3305338 of 3307075 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #0
# 		Pharmaceuticals #0 done!
# 		63530 of 72314 (87.85%) drugs records translated
# 	Group #0 completed!
# 	Translating item 2 of 250
# 		Uploading observational period for group #1
# 		Observational period #1 done!
# 		Uploading visit occurrence for group #1
# 		Visit occurrence #1 done!
# 		Uploading measurements for group #1
# 		Measurement #1 done!
# 		3681303 of 3682933 (99.96%) observations translated
# 		Uploading visit pharmaceuticals for group #1
# 		Pharmaceuticals #1 done!
# 		66025 of 78102 (84.54%) drugs records translated
# 	Group #1 completed!
# 	Translating item 3 of 250
# 		Uploading observational period for group #2
# 		Observational period #2 done!
# 		Uploading visit occurrence for group #2
# 		Visit occurrence #2 done!
# 		Uploading measurements for group #2
# 		Measurement #2 done!
# 		2632057 of 2633385 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #2
# 		Pharmaceuticals #2 done!
# 		43564 of 53204 (81.88%) drugs records translated
# 	Group #2 completed!
# 	Translating item 4 of 250
# 		Uploading observational period for group #3
# 		Observational period #3 done!
# 		Uploading visit occurrence for group #3
# 		Visit occurrence #3 done!
# 		Uploading measurements for group #3
# 		Measurement #3 done!
# 		2685406 of 2686876 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #3
# 		Pharmaceuticals #3 done!
# 		51138 of 58564 (87.32%) drugs records translated
# 	Group #3 completed!
# 	Translating item 5 of 250
# 		Uploading observational period for group #4
# 		Observational period #4 done!
# 		Uploading visit occurrence for group #4
# 		Visit occurrence #4 done!
# 		Uploading measurements for group #4
# 		Measurement #4 done!
# 		2411325 of 2412562 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #4
# 		Pharmaceuticals #4 done!
# 		40080 of 45013 (89.04%) drugs records translated
# 	Group #4 completed!
# 	Translating item 6 of 250
# 		Uploading observational period for group #5
# 		Observational period #5 done!
# 		Uploading visit occurrence for group #5
# 		Visit occurrence #5 done!
# 		Uploading measurements for group #5
# 		Measurement #5 done!
# 		2430734 of 2431984 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #5
# 		Pharmaceuticals #5 done!
# 		41840 of 46069 (90.82%) drugs records translated
# 	Group #5 completed!
# 	Translating item 7 of 250
# 		Uploading observational period for group #6
# 		Observational period #6 done!
# 		Uploading visit occurrence for group #6
# 		Visit occurrence #6 done!
# 		Uploading measurements for group #6
# 		Measurement #6 done!
# 		4745610 of 4747732 (99.96%) observations translated
# 		Uploading visit pharmaceuticals for group #6
# 		Pharmaceuticals #6 done!
# 		89224 of 101049 (88.30%) drugs records translated
# 	Group #6 completed!
# 	Translating item 8 of 250
# 		Uploading observational period for group #7
# 		Observational period #7 done!
# 		Uploading visit occurrence for group #7
# 		Visit occurrence #7 done!
# 		Uploading measurements for group #7
# 		Measurement #7 done!
# 		2190035 of 2191218 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #7
# 		Pharmaceuticals #7 done!
# 		42871 of 46576 (92.05%) drugs records translated
# 	Group #7 completed!
# 	Translating item 9 of 250
# 		Uploading observational period for group #8
# 		Observational period #8 done!
# 		Uploading visit occurrence for group #8
# 		Visit occurrence #8 done!
# 		Uploading measurements for group #8
# 		Measurement #8 done!
# 		3841061 of 3843067 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #8
# 		Pharmaceuticals #8 done!
# 		68428 of 78206 (87.50%) drugs records translated
# 	Group #8 completed!
# 	Translating item 10 of 250
# 		Uploading observational period for group #9
# 		Observational period #9 done!
# 		Uploading visit occurrence for group #9
# 		Visit occurrence #9 done!
# 		Uploading measurements for group #9
# 		Measurement #9 done!
# 		3172502 of 3174137 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #9
# 		Pharmaceuticals #9 done!
# 		64135 of 74089 (86.56%) drugs records translated
# 	Group #9 completed!
# 	Translating item 11 of 250
# 		Uploading observational period for group #10
# 		Observational period #10 done!
# 		Uploading visit occurrence for group #10
# 		Visit occurrence #10 done!
# 		Uploading measurements for group #10
# 		Measurement #10 done!
# 		3620110 of 3621773 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #10
# 		Pharmaceuticals #10 done!
# 		71369 of 80724 (88.41%) drugs records translated
# 	Group #10 completed!
# 	Translating item 12 of 250
# 		Uploading observational period for group #11
# 		Observational period #11 done!
# 		Uploading visit occurrence for group #11
# 		Visit occurrence #11 done!
# 		Uploading measurements for group #11
# 		Measurement #11 done!
# 		2595562 of 2596873 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #11
# 		Pharmaceuticals #11 done!
# 		43988 of 49396 (89.05%) drugs records translated
# 	Group #11 completed!
# 	Translating item 13 of 250
# 		Uploading observational period for group #12
# 		Observational period #12 done!
# 		Uploading visit occurrence for group #12
# 		Visit occurrence #12 done!
# 		Uploading measurements for group #12
# 		Measurement #12 done!
# 		3055316 of 3056916 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #12
# 		Pharmaceuticals #12 done!
# 		57196 of 66742 (85.70%) drugs records translated
# 	Group #12 completed!
# 	Translating item 14 of 250
# 		Uploading observational period for group #13
# 		Observational period #13 done!
# 		Uploading visit occurrence for group #13
# 		Visit occurrence #13 done!
# 		Uploading measurements for group #13
# 		Measurement #13 done!
# 		3729858 of 3731738 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #13
# 		Pharmaceuticals #13 done!
# 		71694 of 83570 (85.79%) drugs records translated
# 	Group #13 completed!
# 	Translating item 15 of 250
# 		Uploading observational period for group #14
# 		Observational period #14 done!
# 		Uploading visit occurrence for group #14
# 		Visit occurrence #14 done!
# 		Uploading measurements for group #14
# 		Measurement #14 done!
# 		3317621 of 3319306 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #14
# 		Pharmaceuticals #14 done!
# 		61137 of 71308 (85.74%) drugs records translated
# 	Group #14 completed!
# 	Translating item 16 of 250
# 		Uploading observational period for group #15
# 		Observational period #15 done!
# 		Uploading visit occurrence for group #15
# 		Visit occurrence #15 done!
# 		Uploading measurements for group #15
# 		Measurement #15 done!
# 		2886794 of 2888284 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #15
# 		Pharmaceuticals #15 done!
# 		56879 of 66055 (86.11%) drugs records translated
# 	Group #15 completed!
# 	Translating item 17 of 250
# 		Uploading observational period for group #16
# 		Observational period #16 done!
# 		Uploading visit occurrence for group #16
# 		Visit occurrence #16 done!
# 		Uploading measurements for group #16
# 		Measurement #16 done!
# 		2349831 of 2351027 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #16
# 		Pharmaceuticals #16 done!
# 		39902 of 46668 (85.50%) drugs records translated
# 	Group #16 completed!
# 	Translating item 18 of 250
# 		Uploading observational period for group #17
# 		Observational period #17 done!
# 		Uploading visit occurrence for group #17
# 		Visit occurrence #17 done!
# 		Uploading measurements for group #17
# 		Measurement #17 done!
# 		2887024 of 2888497 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #17
# 		Pharmaceuticals #17 done!
# 		53370 of 61241 (87.15%) drugs records translated
# 	Group #17 completed!
# 	Translating item 19 of 250
# 		Uploading observational period for group #18
# 		Observational period #18 done!
# 		Uploading visit occurrence for group #18
# 		Visit occurrence #18 done!
# 		Uploading measurements for group #18
# 		Measurement #18 done!
# 		3188383 of 3189968 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #18
# 		Pharmaceuticals #18 done!
# 		63389 of 73737 (85.97%) drugs records translated
# 	Group #18 completed!
# 	Translating item 20 of 250
# 		Uploading observational period for group #19
# 		Observational period #19 done!
# 		Uploading visit occurrence for group #19
# 		Visit occurrence #19 done!
# 		Uploading measurements for group #19
# 		Measurement #19 done!
# 		2978796 of 2980473 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #19
# 		Pharmaceuticals #19 done!
# 		47921 of 55199 (86.81%) drugs records translated
# 	Group #19 completed!
# 	Translating item 21 of 250
# 		Uploading observational period for group #20
# 		Observational period #20 done!
# 		Uploading visit occurrence for group #20
# 		Visit occurrence #20 done!
# 		Uploading measurements for group #20
# 		Measurement #20 done!
# 		1836030 of 1837052 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #20
# 		Pharmaceuticals #20 done!
# 		29551 of 33544 (88.10%) drugs records translated
# 	Group #20 completed!
# 	Translating item 22 of 250
# 		Uploading observational period for group #21
# 		Observational period #21 done!
# 		Uploading visit occurrence for group #21
# 		Visit occurrence #21 done!
# 		Uploading measurements for group #21
# 		Measurement #21 done!
# 		3139371 of 3140877 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #21
# 		Pharmaceuticals #21 done!
# 		54346 of 62174 (87.41%) drugs records translated
# 	Group #21 completed!
# 	Translating item 23 of 250
# 		Uploading observational period for group #22
# 		Observational period #22 done!
# 		Uploading visit occurrence for group #22
# 		Visit occurrence #22 done!
# 		Uploading measurements for group #22
# 		Measurement #22 done!
# 		2963473 of 2964964 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #22
# 		Pharmaceuticals #22 done!
# 		51910 of 58103 (89.34%) drugs records translated
# 	Group #22 completed!
# 	Translating item 24 of 250
# 		Uploading observational period for group #23
# 		Observational period #23 done!
# 		Uploading visit occurrence for group #23
# 		Visit occurrence #23 done!
# 		Uploading measurements for group #23
# 		Measurement #23 done!
# 		2650377 of 2651818 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #23
# 		Pharmaceuticals #23 done!
# 		53544 of 60831 (88.02%) drugs records translated
# 	Group #23 completed!
# 	Translating item 25 of 250
# 		Uploading observational period for group #24
# 		Observational period #24 done!
# 		Uploading visit occurrence for group #24
# 		Visit occurrence #24 done!
# 		Uploading measurements for group #24
# 		Measurement #24 done!
# 		3514284 of 3516040 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #24
# 		Pharmaceuticals #24 done!
# 		67242 of 79013 (85.10%) drugs records translated
# 	Group #24 completed!
# 	Translating item 26 of 250
# 		Uploading observational period for group #25
# 		Observational period #25 done!
# 		Uploading visit occurrence for group #25
# 		Visit occurrence #25 done!
# 		Uploading measurements for group #25
# 		Measurement #25 done!
# 		2131389 of 2132587 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #25
# 		Pharmaceuticals #25 done!
# 		38216 of 42744 (89.41%) drugs records translated
# 	Group #25 completed!
# 	Translating item 27 of 250
# 		Uploading observational period for group #26
# 		Observational period #26 done!
# 		Uploading visit occurrence for group #26
# 		Visit occurrence #26 done!
# 		Uploading measurements for group #26
# 		Measurement #26 done!
# 		4517428 of 4519684 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #26
# 		Pharmaceuticals #26 done!
# 		84064 of 98135 (85.66%) drugs records translated
# 	Group #26 completed!
# 	Translating item 28 of 250
# 		Uploading observational period for group #27
# 		Observational period #27 done!
# 		Uploading visit occurrence for group #27
# 		Visit occurrence #27 done!
# 		Uploading measurements for group #27
# 		Measurement #27 done!
# 		2973426 of 2974820 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #27
# 		Pharmaceuticals #27 done!
# 		52125 of 59477 (87.64%) drugs records translated
# 	Group #27 completed!
# 	Translating item 29 of 250
# 		Uploading observational period for group #28
# 		Observational period #28 done!
# 		Uploading visit occurrence for group #28
# 		Visit occurrence #28 done!
# 		Uploading measurements for group #28
# 		Measurement #28 done!
# 		2435318 of 2436618 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #28
# 		Pharmaceuticals #28 done!
# 		44941 of 52238 (86.03%) drugs records translated
# 	Group #28 completed!
# 	Translating item 30 of 250
# 		Uploading observational period for group #29
# 		Observational period #29 done!
# 		Uploading visit occurrence for group #29
# 		Visit occurrence #29 done!
# 		Uploading measurements for group #29
# 		Measurement #29 done!
# 		2758961 of 2760436 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #29
# 		Pharmaceuticals #29 done!
# 		47200 of 53571 (88.11%) drugs records translated
# 	Group #29 completed!
# 	Translating item 31 of 250
# 		Uploading observational period for group #30
# 		Observational period #30 done!
# 		Uploading visit occurrence for group #30
# 		Visit occurrence #30 done!
# 		Uploading measurements for group #30
# list index out of range
# !storno
# 		Measurement #30 done!
# 		2762460 of 2763795 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #30
# 		Pharmaceuticals #30 done!
# 		42717 of 47993 (89.01%) drugs records translated
# 	Group #30 completed!
# 	Translating item 32 of 250
# 		Uploading observational period for group #31
# 		Observational period #31 done!
# 		Uploading visit occurrence for group #31
# 		Visit occurrence #31 done!
# 		Uploading measurements for group #31
# 		Measurement #31 done!
# 		2745231 of 2746669 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #31
# 		Pharmaceuticals #31 done!
# 		49242 of 55566 (88.62%) drugs records translated
# 	Group #31 completed!
# 	Translating item 33 of 250
# 		Uploading observational period for group #32
# 		Observational period #32 done!
# 		Uploading visit occurrence for group #32
# 		Visit occurrence #32 done!
# 		Uploading measurements for group #32
# 		Measurement #32 done!
# 		4384421 of 4386628 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #32
# 		Pharmaceuticals #32 done!
# 		81104 of 93545 (86.70%) drugs records translated
# 	Group #32 completed!
# 	Translating item 34 of 250
# 		Uploading observational period for group #33
# 		Observational period #33 done!
# 		Uploading visit occurrence for group #33
# 		Visit occurrence #33 done!
# 		Uploading measurements for group #33
# 		Measurement #33 done!
# 		3855695 of 3857617 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #33
# 		Pharmaceuticals #33 done!
# 		70116 of 82188 (85.31%) drugs records translated
# 	Group #33 completed!
# 	Translating item 35 of 250
# 		Uploading observational period for group #34
# 		Observational period #34 done!
# 		Uploading visit occurrence for group #34
# 		Visit occurrence #34 done!
# 		Uploading measurements for group #34
# 		Measurement #34 done!
# 		3015084 of 3016568 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #34
# 		Pharmaceuticals #34 done!
# 		65813 of 74062 (88.86%) drugs records translated
# 	Group #34 completed!
# 	Translating item 36 of 250
# 		Uploading observational period for group #35
# 		Observational period #35 done!
# 		Uploading visit occurrence for group #35
# 		Visit occurrence #35 done!
# 		Uploading measurements for group #35
# 		Measurement #35 done!
# 		3132290 of 3133860 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #35
# 		Pharmaceuticals #35 done!
# 		62294 of 75097 (82.95%) drugs records translated
# 	Group #35 completed!
# 	Translating item 37 of 250
# 		Uploading observational period for group #36
# 		Observational period #36 done!
# 		Uploading visit occurrence for group #36
# 		Visit occurrence #36 done!
# 		Uploading measurements for group #36
# 		Measurement #36 done!
# 		3274310 of 3275859 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #36
# 		Pharmaceuticals #36 done!
# 		56063 of 67299 (83.30%) drugs records translated
# 	Group #36 completed!
# 	Translating item 38 of 250
# 		Uploading observational period for group #37
# 		Observational period #37 done!
# 		Uploading visit occurrence for group #37
# 		Visit occurrence #37 done!
# 		Uploading measurements for group #37
# 		Measurement #37 done!
# 		2570593 of 2572114 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #37
# 		Pharmaceuticals #37 done!
# 		46425 of 52591 (88.28%) drugs records translated
# 	Group #37 completed!
# 	Translating item 39 of 250
# 		Uploading observational period for group #38
# 		Observational period #38 done!
# 		Uploading visit occurrence for group #38
# 		Visit occurrence #38 done!
# 		Uploading measurements for group #38
# 		Measurement #38 done!
# 		4447237 of 4449468 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #38
# 		Pharmaceuticals #38 done!
# 		90298 of 105595 (85.51%) drugs records translated
# 	Group #38 completed!
# 	Translating item 40 of 250
# 		Uploading observational period for group #39
# 		Observational period #39 done!
# 		Uploading visit occurrence for group #39
# 		Visit occurrence #39 done!
# 		Uploading measurements for group #39
# 		Measurement #39 done!
# 		3101104 of 3102654 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #39
# 		Pharmaceuticals #39 done!
# 		49947 of 56864 (87.84%) drugs records translated
# 	Group #39 completed!
# 	Translating item 41 of 250
# 		Uploading observational period for group #40
# 		Observational period #40 done!
# 		Uploading visit occurrence for group #40
# 		Visit occurrence #40 done!
# 		Uploading measurements for group #40
# 		Measurement #40 done!
# 		2906411 of 2907974 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #40
# 		Pharmaceuticals #40 done!
# 		52750 of 61074 (86.37%) drugs records translated
# 	Group #40 completed!
# 	Translating item 42 of 250
# 		Uploading observational period for group #41
# 		Observational period #41 done!
# 		Uploading visit occurrence for group #41
# 		Visit occurrence #41 done!
# 		Uploading measurements for group #41
# 		Measurement #41 done!
# 		3920715 of 3922538 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #41
# 		Pharmaceuticals #41 done!
# 		75129 of 82227 (91.37%) drugs records translated
# 	Group #41 completed!
# 	Translating item 43 of 250
# 		Uploading observational period for group #42
# 		Observational period #42 done!
# 		Uploading visit occurrence for group #42
# 		Visit occurrence #42 done!
# 		Uploading measurements for group #42
# 		Measurement #42 done!
# 		3255114 of 3256688 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #42
# 		Pharmaceuticals #42 done!
# 		54136 of 64876 (83.45%) drugs records translated
# 	Group #42 completed!
# 	Translating item 44 of 250
# 		Uploading observational period for group #43
# 		Observational period #43 done!
# 		Uploading visit occurrence for group #43
# 		Visit occurrence #43 done!
# 		Uploading measurements for group #43
# 		Measurement #43 done!
# 		3834427 of 3836397 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #43
# 		Pharmaceuticals #43 done!
# 		79032 of 89814 (88.00%) drugs records translated
# 	Group #43 completed!
# 	Translating item 45 of 250
# 		Uploading observational period for group #44
# 		Observational period #44 done!
# 		Uploading visit occurrence for group #44
# 		Visit occurrence #44 done!
# 		Uploading measurements for group #44
# 		Measurement #44 done!
# 		4234654 of 4236617 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #44
# 		Pharmaceuticals #44 done!
# 		68896 of 79262 (86.92%) drugs records translated
# 	Group #44 completed!
# 	Translating item 46 of 250
# 		Uploading observational period for group #45
# 		Observational period #45 done!
# 		Uploading visit occurrence for group #45
# 		Visit occurrence #45 done!
# 		Uploading measurements for group #45
# 		Measurement #45 done!
# 		3700454 of 3702208 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #45
# 		Pharmaceuticals #45 done!
# 		69640 of 80124 (86.92%) drugs records translated
# 	Group #45 completed!
# 	Translating item 47 of 250
# 		Uploading observational period for group #46
# 		Observational period #46 done!
# 		Uploading visit occurrence for group #46
# 		Visit occurrence #46 done!
# 		Uploading measurements for group #46
# 		Measurement #46 done!
# 		2695615 of 2696908 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #46
# 		Pharmaceuticals #46 done!
# 		45082 of 51798 (87.03%) drugs records translated
# 	Group #46 completed!
# 	Translating item 48 of 250
# 		Uploading observational period for group #47
# 		Observational period #47 done!
# 		Uploading visit occurrence for group #47
# 		Visit occurrence #47 done!
# 		Uploading measurements for group #47
# 		Measurement #47 done!
# 		3592870 of 3594512 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #47
# 		Pharmaceuticals #47 done!
# 		62279 of 74389 (83.72%) drugs records translated
# 	Group #47 completed!
# 	Translating item 49 of 250
# 		Uploading observational period for group #48
# 		Observational period #48 done!
# 		Uploading visit occurrence for group #48
# 		Visit occurrence #48 done!
# 		Uploading measurements for group #48
# 		Measurement #48 done!
# 		3277609 of 3279371 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #48
# 		Pharmaceuticals #48 done!
# 		60484 of 69808 (86.64%) drugs records translated
# 	Group #48 completed!
# 	Translating item 50 of 250
# 		Uploading observational period for group #49
# 		Observational period #49 done!
# 		Uploading visit occurrence for group #49
# 		Visit occurrence #49 done!
# 		Uploading measurements for group #49
# 		Measurement #49 done!
# 		2707030 of 2708537 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #49
# 		Pharmaceuticals #49 done!
# 		48846 of 55694 (87.70%) drugs records translated
# 	Group #49 completed!
# 	Translating item 51 of 250
# 		Uploading observational period for group #50
# 		Observational period #50 done!
# 		Uploading visit occurrence for group #50
# 		Visit occurrence #50 done!
# 		Uploading measurements for group #50
# 		Measurement #50 done!
# 		3571822 of 3573493 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #50
# 		Pharmaceuticals #50 done!
# 		59516 of 71505 (83.23%) drugs records translated
# 	Group #50 completed!
# 	Translating item 52 of 250
# 		Uploading observational period for group #51
# 		Observational period #51 done!
# 		Uploading visit occurrence for group #51
# 		Visit occurrence #51 done!
# 		Uploading measurements for group #51
# 		Measurement #51 done!
# 		3561805 of 3563595 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #51
# 		Pharmaceuticals #51 done!
# 		62206 of 73859 (84.22%) drugs records translated
# 	Group #51 completed!
# 	Translating item 53 of 250
# 		Uploading observational period for group #52
# 		Observational period #52 done!
# 		Uploading visit occurrence for group #52
# 		Visit occurrence #52 done!
# 		Uploading measurements for group #52
# 		Measurement #52 done!
# 		3647244 of 3649074 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #52
# 		Pharmaceuticals #52 done!
# 		59764 of 70273 (85.05%) drugs records translated
# 	Group #52 completed!
# 	Translating item 54 of 250
# 		Uploading observational period for group #53
# 		Observational period #53 done!
# 		Uploading visit occurrence for group #53
# 		Visit occurrence #53 done!
# 		Uploading measurements for group #53
# 		Measurement #53 done!
# 		3489296 of 3490991 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #53
# 		Pharmaceuticals #53 done!
# 		65210 of 73517 (88.70%) drugs records translated
# 	Group #53 completed!
# 	Translating item 55 of 250
# 		Uploading observational period for group #54
# 		Observational period #54 done!
# 		Uploading visit occurrence for group #54
# 		Visit occurrence #54 done!
# 		Uploading measurements for group #54
# 		Measurement #54 done!
# 		2789719 of 2791140 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #54
# 		Pharmaceuticals #54 done!
# 		44481 of 49961 (89.03%) drugs records translated
# 	Group #54 completed!
# 	Translating item 56 of 250
# 		Uploading observational period for group #55
# 		Observational period #55 done!
# 		Uploading visit occurrence for group #55
# 		Visit occurrence #55 done!
# 		Uploading measurements for group #55
# 		Measurement #55 done!
# 		2675950 of 2677342 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #55
# 		Pharmaceuticals #55 done!
# 		44590 of 53163 (83.87%) drugs records translated
# 	Group #55 completed!
# 	Translating item 57 of 250
# 		Uploading observational period for group #56
# 		Observational period #56 done!
# 		Uploading visit occurrence for group #56
# 		Visit occurrence #56 done!
# 		Uploading measurements for group #56
# 		Measurement #56 done!
# 		3066630 of 3068278 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #56
# 		Pharmaceuticals #56 done!
# 		48054 of 56001 (85.81%) drugs records translated
# 	Group #56 completed!
# 	Translating item 58 of 250
# 		Uploading observational period for group #57
# 		Observational period #57 done!
# 		Uploading visit occurrence for group #57
# 		Visit occurrence #57 done!
# 		Uploading measurements for group #57
# 		Measurement #57 done!
# 		4028408 of 4030316 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #57
# 		Pharmaceuticals #57 done!
# 		71434 of 82407 (86.68%) drugs records translated
# 	Group #57 completed!
# 	Translating item 59 of 250
# 		Uploading observational period for group #58
# 		Observational period #58 done!
# 		Uploading visit occurrence for group #58
# 		Visit occurrence #58 done!
# 		Uploading measurements for group #58
# 		Measurement #58 done!
# 		2419770 of 2421121 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #58
# 		Pharmaceuticals #58 done!
# 		44652 of 50415 (88.57%) drugs records translated
# 	Group #58 completed!
# 	Translating item 60 of 250
# 		Uploading observational period for group #59
# 		Observational period #59 done!
# 		Uploading visit occurrence for group #59
# 		Visit occurrence #59 done!
# 		Uploading measurements for group #59
# 		Measurement #59 done!
# 		3239216 of 3240850 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #59
# 		Pharmaceuticals #59 done!
# 		70179 of 78547 (89.35%) drugs records translated
# 	Group #59 completed!
# 	Translating item 61 of 250
# 		Uploading observational period for group #60
# 		Observational period #60 done!
# 		Uploading visit occurrence for group #60
# 		Visit occurrence #60 done!
# 		Uploading measurements for group #60
# 		Measurement #60 done!
# 		2578423 of 2579723 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #60
# 		Pharmaceuticals #60 done!
# 		43419 of 48040 (90.38%) drugs records translated
# 	Group #60 completed!
# 	Translating item 62 of 250
# 		Uploading observational period for group #61
# 		Observational period #61 done!
# 		Uploading visit occurrence for group #61
# 		Visit occurrence #61 done!
# 		Uploading measurements for group #61
# 		Measurement #61 done!
# 		3270662 of 3272236 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #61
# 		Pharmaceuticals #61 done!
# 		61328 of 69761 (87.91%) drugs records translated
# 	Group #61 completed!
# 	Translating item 63 of 250
# 		Uploading observational period for group #62
# 		Observational period #62 done!
# 		Uploading visit occurrence for group #62
# 		Visit occurrence #62 done!
# 		Uploading measurements for group #62
# 		Measurement #62 done!
# 		4418051 of 4420165 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #62
# 		Pharmaceuticals #62 done!
# 		85061 of 95381 (89.18%) drugs records translated
# 	Group #62 completed!
# 	Translating item 64 of 250
# 		Uploading observational period for group #63
# 		Observational period #63 done!
# 		Uploading visit occurrence for group #63
# 		Visit occurrence #63 done!
# 		Uploading measurements for group #63
# 		Measurement #63 done!
# 		3735452 of 3737430 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #63
# 		Pharmaceuticals #63 done!
# 		74049 of 83392 (88.80%) drugs records translated
# 	Group #63 completed!
# 	Translating item 65 of 250
# 		Uploading observational period for group #64
# 		Observational period #64 done!
# 		Uploading visit occurrence for group #64
# 		Visit occurrence #64 done!
# 		Uploading measurements for group #64
# 		Measurement #64 done!
# 		2528950 of 2530424 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #64
# 		Pharmaceuticals #64 done!
# 		46028 of 51859 (88.76%) drugs records translated
# 	Group #64 completed!
# 	Translating item 66 of 250
# 		Uploading observational period for group #65
# 		Observational period #65 done!
# 		Uploading visit occurrence for group #65
# 		Visit occurrence #65 done!
# 		Uploading measurements for group #65
# 		Measurement #65 done!
# 		3766380 of 3768432 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #65
# 		Pharmaceuticals #65 done!
# 		61974 of 72396 (85.60%) drugs records translated
# 	Group #65 completed!
# 	Translating item 67 of 250
# 		Uploading observational period for group #66
# 		Observational period #66 done!
# 		Uploading visit occurrence for group #66
# 		Visit occurrence #66 done!
# 		Uploading measurements for group #66
# 		Measurement #66 done!
# 		3396151 of 3397837 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #66
# 		Pharmaceuticals #66 done!
# 		58999 of 65793 (89.67%) drugs records translated
# 	Group #66 completed!
# 	Translating item 68 of 250
# 		Uploading observational period for group #67
# 		Observational period #67 done!
# 		Uploading visit occurrence for group #67
# 		Visit occurrence #67 done!
# 		Uploading measurements for group #67
# 		Measurement #67 done!
# 		2977988 of 2979484 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #67
# 		Pharmaceuticals #67 done!
# 		49301 of 57861 (85.21%) drugs records translated
# 	Group #67 completed!
# 	Translating item 69 of 250
# 		Uploading observational period for group #68
# 		Observational period #68 done!
# 		Uploading visit occurrence for group #68
# 		Visit occurrence #68 done!
# 		Uploading measurements for group #68
# 		Measurement #68 done!
# 		2325409 of 2326586 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #68
# 		Pharmaceuticals #68 done!
# 		41158 of 46325 (88.85%) drugs records translated
# 	Group #68 completed!
# 	Translating item 70 of 250
# 		Uploading observational period for group #69
# 		Observational period #69 done!
# 		Uploading visit occurrence for group #69
# 		Visit occurrence #69 done!
# 		Uploading measurements for group #69
# 		Measurement #69 done!
# 		2854452 of 2856201 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #69
# 		Pharmaceuticals #69 done!
# 		46583 of 54919 (84.82%) drugs records translated
# 	Group #69 completed!
# 	Translating item 71 of 250
# 		Uploading observational period for group #70
# 		Observational period #70 done!
# 		Uploading visit occurrence for group #70
# 		Visit occurrence #70 done!
# 		Uploading measurements for group #70
# 		Measurement #70 done!
# 		3178751 of 3180341 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #70
# 		Pharmaceuticals #70 done!
# 		53236 of 61997 (85.87%) drugs records translated
# 	Group #70 completed!
# 	Translating item 72 of 250
# 		Uploading observational period for group #71
# 		Observational period #71 done!
# 		Uploading visit occurrence for group #71
# 		Visit occurrence #71 done!
# 		Uploading measurements for group #71
# 		Measurement #71 done!
# 		2739699 of 2741136 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #71
# 		Pharmaceuticals #71 done!
# 		52716 of 59342 (88.83%) drugs records translated
# 	Group #71 completed!
# 	Translating item 73 of 250
# 		Uploading observational period for group #72
# 		Observational period #72 done!
# 		Uploading visit occurrence for group #72
# 		Visit occurrence #72 done!
# 		Uploading measurements for group #72
# 		Measurement #72 done!
# 		3651282 of 3653092 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #72
# 		Pharmaceuticals #72 done!
# 		68189 of 78202 (87.20%) drugs records translated
# 	Group #72 completed!
# 	Translating item 74 of 250
# 		Uploading observational period for group #73
# 		Observational period #73 done!
# 		Uploading visit occurrence for group #73
# 		Visit occurrence #73 done!
# 		Uploading measurements for group #73
# 		Measurement #73 done!
# 		2966512 of 2967979 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #73
# 		Pharmaceuticals #73 done!
# 		52027 of 64107 (81.16%) drugs records translated
# 	Group #73 completed!
# 	Translating item 75 of 250
# 		Uploading observational period for group #74
# 		Observational period #74 done!
# 		Uploading visit occurrence for group #74
# 		Visit occurrence #74 done!
# 		Uploading measurements for group #74
# 		Measurement #74 done!
# 		2870015 of 2871442 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #74
# 		Pharmaceuticals #74 done!
# 		52683 of 61839 (85.19%) drugs records translated
# 	Group #74 completed!
# 	Translating item 76 of 250
# 		Uploading observational period for group #75
# 		Observational period #75 done!
# 		Uploading visit occurrence for group #75
# 		Visit occurrence #75 done!
# 		Uploading measurements for group #75
# 		Measurement #75 done!
# 		2740289 of 2741672 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #75
# 		Pharmaceuticals #75 done!
# 		54538 of 63492 (85.90%) drugs records translated
# 	Group #75 completed!
# 	Translating item 77 of 250
# 		Uploading observational period for group #76
# 		Observational period #76 done!
# 		Uploading visit occurrence for group #76
# 		Visit occurrence #76 done!
# 		Uploading measurements for group #76
# 		Measurement #76 done!
# 		2640924 of 2642405 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #76
# 		Pharmaceuticals #76 done!
# 		44715 of 51975 (86.03%) drugs records translated
# 	Group #76 completed!
# 	Translating item 78 of 250
# 		Uploading observational period for group #77
# 		Observational period #77 done!
# 		Uploading visit occurrence for group #77
# 		Visit occurrence #77 done!
# 		Uploading measurements for group #77
# 		Measurement #77 done!
# 		2840927 of 2842371 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #77
# 		Pharmaceuticals #77 done!
# 		49508 of 56401 (87.78%) drugs records translated
# 	Group #77 completed!
# 	Translating item 79 of 250
# 		Uploading observational period for group #78
# 		Observational period #78 done!
# 		Uploading visit occurrence for group #78
# 		Visit occurrence #78 done!
# 		Uploading measurements for group #78
# 		Measurement #78 done!
# 		2844600 of 2845999 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #78
# 		Pharmaceuticals #78 done!
# 		52297 of 61772 (84.66%) drugs records translated
# 	Group #78 completed!
# 	Translating item 80 of 250
# 		Uploading observational period for group #79
# 		Observational period #79 done!
# 		Uploading visit occurrence for group #79
# 		Visit occurrence #79 done!
# 		Uploading measurements for group #79
# 		Measurement #79 done!
# 		2838960 of 2840326 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #79
# 		Pharmaceuticals #79 done!
# 		47340 of 56460 (83.85%) drugs records translated
# 	Group #79 completed!
# 	Translating item 81 of 250
# 		Uploading observational period for group #80
# 		Observational period #80 done!
# 		Uploading visit occurrence for group #80
# 		Visit occurrence #80 done!
# 		Uploading measurements for group #80
# 		Measurement #80 done!
# 		3148429 of 3150136 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #80
# 		Pharmaceuticals #80 done!
# 		59461 of 66340 (89.63%) drugs records translated
# 	Group #80 completed!
# 	Translating item 82 of 250
# 		Uploading observational period for group #81
# 		Observational period #81 done!
# 		Uploading visit occurrence for group #81
# 		Visit occurrence #81 done!
# 		Uploading measurements for group #81
# 		Measurement #81 done!
# 		3879095 of 3881079 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #81
# 		Pharmaceuticals #81 done!
# 		71533 of 84499 (84.66%) drugs records translated
# 	Group #81 completed!
# 	Translating item 83 of 250
# 		Uploading observational period for group #82
# 		Observational period #82 done!
# 		Uploading visit occurrence for group #82
# 		Visit occurrence #82 done!
# 		Uploading measurements for group #82
# 		Measurement #82 done!
# 		3177708 of 3179355 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #82
# 		Pharmaceuticals #82 done!
# 		59212 of 66499 (89.04%) drugs records translated
# 	Group #82 completed!
# 	Translating item 84 of 250
# 		Uploading observational period for group #83
# 		Observational period #83 done!
# 		Uploading visit occurrence for group #83
# 		Visit occurrence #83 done!
# 		Uploading measurements for group #83
# 		Measurement #83 done!
# 		3824648 of 3826405 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #83
# 		Pharmaceuticals #83 done!
# 		69295 of 78443 (88.34%) drugs records translated
# 	Group #83 completed!
# 	Translating item 85 of 250
# 		Uploading observational period for group #84
# 		Observational period #84 done!
# 		Uploading visit occurrence for group #84
# 		Visit occurrence #84 done!
# 		Uploading measurements for group #84
# 		Measurement #84 done!
# 		2483266 of 2484716 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #84
# 		Pharmaceuticals #84 done!
# 		45280 of 50878 (89.00%) drugs records translated
# 	Group #84 completed!
# 	Translating item 86 of 250
# 		Uploading observational period for group #85
# 		Observational period #85 done!
# 		Uploading visit occurrence for group #85
# 		Visit occurrence #85 done!
# 		Uploading measurements for group #85
# 		Measurement #85 done!
# 		3572468 of 3574379 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #85
# 		Pharmaceuticals #85 done!
# 		61449 of 69328 (88.64%) drugs records translated
# 	Group #85 completed!
# 	Translating item 87 of 250
# 		Uploading observational period for group #86
# 		Observational period #86 done!
# 		Uploading visit occurrence for group #86
# 		Visit occurrence #86 done!
# 		Uploading measurements for group #86
# 		Measurement #86 done!
# 		2432481 of 2433670 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #86
# 		Pharmaceuticals #86 done!
# 		40077 of 45144 (88.78%) drugs records translated
# 	Group #86 completed!
# 	Translating item 88 of 250
# 		Uploading observational period for group #87
# 		Observational period #87 done!
# 		Uploading visit occurrence for group #87
# 		Visit occurrence #87 done!
# 		Uploading measurements for group #87
# 		Measurement #87 done!
# 		2750312 of 2751694 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #87
# 		Pharmaceuticals #87 done!
# 		48037 of 54788 (87.68%) drugs records translated
# 	Group #87 completed!
# 	Translating item 89 of 250
# 		Uploading observational period for group #88
# 		Observational period #88 done!
# 		Uploading visit occurrence for group #88
# 		Visit occurrence #88 done!
# 		Uploading measurements for group #88
# 		Measurement #88 done!
# 		2855091 of 2856702 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #88
# 		Pharmaceuticals #88 done!
# 		53931 of 60599 (89.00%) drugs records translated
# 	Group #88 completed!
# 	Translating item 90 of 250
# 		Uploading observational period for group #89
# 		Observational period #89 done!
# 		Uploading visit occurrence for group #89
# 		Visit occurrence #89 done!
# 		Uploading measurements for group #89
# 		Measurement #89 done!
# 		2429401 of 2430711 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #89
# 		Pharmaceuticals #89 done!
# 		43001 of 48542 (88.59%) drugs records translated
# 	Group #89 completed!
# 	Translating item 91 of 250
# 		Uploading observational period for group #90
# 		Observational period #90 done!
# 		Uploading visit occurrence for group #90
# 		Visit occurrence #90 done!
# 		Uploading measurements for group #90
# 		Measurement #90 done!
# 		3220341 of 3221941 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #90
# 		Pharmaceuticals #90 done!
# 		61870 of 72782 (85.01%) drugs records translated
# 	Group #90 completed!
# 	Translating item 92 of 250
# 		Uploading observational period for group #91
# 		Observational period #91 done!
# 		Uploading visit occurrence for group #91
# 		Visit occurrence #91 done!
# 		Uploading measurements for group #91
# 		Measurement #91 done!
# 		3257553 of 3259203 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #91
# 		Pharmaceuticals #91 done!
# 		61202 of 68662 (89.14%) drugs records translated
# 	Group #91 completed!
# 	Translating item 93 of 250
# 		Uploading observational period for group #92
# 		Observational period #92 done!
# 		Uploading visit occurrence for group #92
# 		Visit occurrence #92 done!
# 		Uploading measurements for group #92
# 		Measurement #92 done!
# 		2655974 of 2657332 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #92
# 		Pharmaceuticals #92 done!
# 		51472 of 58508 (87.97%) drugs records translated
# 	Group #92 completed!
# 	Translating item 94 of 250
# 		Uploading observational period for group #93
# 		Observational period #93 done!
# 		Uploading visit occurrence for group #93
# 		Visit occurrence #93 done!
# 		Uploading measurements for group #93
# 		Measurement #93 done!
# 		3279961 of 3281771 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #93
# 		Pharmaceuticals #93 done!
# 		56829 of 64257 (88.44%) drugs records translated
# 	Group #93 completed!
# 	Translating item 95 of 250
# 		Uploading observational period for group #94
# 		Observational period #94 done!
# 		Uploading visit occurrence for group #94
# 		Visit occurrence #94 done!
# 		Uploading measurements for group #94
# 		Measurement #94 done!
# 		2647074 of 2648428 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #94
# 		Pharmaceuticals #94 done!
# 		44042 of 49967 (88.14%) drugs records translated
# 	Group #94 completed!
# 	Translating item 96 of 250
# 		Uploading observational period for group #95
# 		Observational period #95 done!
# 		Uploading visit occurrence for group #95
# 		Visit occurrence #95 done!
# 		Uploading measurements for group #95
# 		Measurement #95 done!
# 		2271356 of 2272431 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #95
# 		Pharmaceuticals #95 done!
# 		37497 of 41455 (90.45%) drugs records translated
# 	Group #95 completed!
# 	Translating item 97 of 250
# 		Uploading observational period for group #96
# 		Observational period #96 done!
# 		Uploading visit occurrence for group #96
# 		Visit occurrence #96 done!
# 		Uploading measurements for group #96
# 		Measurement #96 done!
# 		2741877 of 2743301 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #96
# 		Pharmaceuticals #96 done!
# 		49586 of 56514 (87.74%) drugs records translated
# 	Group #96 completed!
# 	Translating item 98 of 250
# 		Uploading observational period for group #97
# 		Observational period #97 done!
# 		Uploading visit occurrence for group #97
# 		Visit occurrence #97 done!
# 		Uploading measurements for group #97
# 		Measurement #97 done!
# 		3494199 of 3495930 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #97
# 		Pharmaceuticals #97 done!
# 		60589 of 68475 (88.48%) drugs records translated
# 	Group #97 completed!
# 	Translating item 99 of 250
# 		Uploading observational period for group #98
# 		Observational period #98 done!
# 		Uploading visit occurrence for group #98
# 		Visit occurrence #98 done!
# 		Uploading measurements for group #98
# 		Measurement #98 done!
# 		2503528 of 2504854 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #98
# 		Pharmaceuticals #98 done!
# 		44180 of 50164 (88.07%) drugs records translated
# 	Group #98 completed!
# 	Translating item 100 of 250
# 		Uploading observational period for group #99
# 		Observational period #99 done!
# 		Uploading visit occurrence for group #99
# 		Visit occurrence #99 done!
# 		Uploading measurements for group #99
# 		Measurement #99 done!
# 		3075545 of 3077081 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #99
# 		Pharmaceuticals #99 done!
# 		54886 of 64641 (84.91%) drugs records translated
# 	Group #99 completed!
# 	Translating item 101 of 250
# 		Uploading observational period for group #100
# 		Observational period #100 done!
# 		Uploading visit occurrence for group #100
# 		Visit occurrence #100 done!
# 		Uploading measurements for group #100
# 		Measurement #100 done!
# 		2114036 of 2115200 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #100
# 		Pharmaceuticals #100 done!
# 		33681 of 41209 (81.73%) drugs records translated
# 	Group #100 completed!
# 	Translating item 102 of 250
# 		Uploading observational period for group #101
# 		Observational period #101 done!
# 		Uploading visit occurrence for group #101
# 		Visit occurrence #101 done!
# 		Uploading measurements for group #101
# 		Measurement #101 done!
# 		2379247 of 2380542 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #101
# 		Pharmaceuticals #101 done!
# 		40242 of 46447 (86.64%) drugs records translated
# 	Group #101 completed!
# 	Translating item 103 of 250
# 		Uploading observational period for group #102
# 		Observational period #102 done!
# 		Uploading visit occurrence for group #102
# 		Visit occurrence #102 done!
# 		Uploading measurements for group #102
# 		Measurement #102 done!
# 		3313861 of 3315553 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #102
# 		Pharmaceuticals #102 done!
# 		63774 of 71650 (89.01%) drugs records translated
# 	Group #102 completed!
# 	Translating item 104 of 250
# 		Uploading observational period for group #103
# 		Observational period #103 done!
# 		Uploading visit occurrence for group #103
# 		Visit occurrence #103 done!
# 		Uploading measurements for group #103
# 		Measurement #103 done!
# 		3647781 of 3649555 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #103
# 		Pharmaceuticals #103 done!
# 		68921 of 79160 (87.07%) drugs records translated
# 	Group #103 completed!
# 	Translating item 105 of 250
# 		Uploading observational period for group #104
# 		Observational period #104 done!
# 		Uploading visit occurrence for group #104
# 		Visit occurrence #104 done!
# 		Uploading measurements for group #104
# 		Measurement #104 done!
# 		3400546 of 3402406 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #104
# 		Pharmaceuticals #104 done!
# 		62168 of 72447 (85.81%) drugs records translated
# 	Group #104 completed!
# 	Translating item 106 of 250
# 		Uploading observational period for group #105
# 		Observational period #105 done!
# 		Uploading visit occurrence for group #105
# 		Visit occurrence #105 done!
# 		Uploading measurements for group #105
# 		Measurement #105 done!
# 		2815237 of 2816678 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #105
# 		Pharmaceuticals #105 done!
# 		49531 of 59831 (82.78%) drugs records translated
# 	Group #105 completed!
# 	Translating item 107 of 250
# 		Uploading observational period for group #106
# 		Observational period #106 done!
# 		Uploading visit occurrence for group #106
# 		Visit occurrence #106 done!
# 		Uploading measurements for group #106
# 		Measurement #106 done!
# 		2868148 of 2869649 (99.95%) observations translated
# ...
# 		Measurement #215 done!
# 		3300297 of 3302068 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #215
# 		Pharmaceuticals #215 done!
# 		54313 of 67854 (80.04%) drugs records translated
# 	Group #215 completed!
# 	Translating item 217 of 250
# 		Uploading observational period for group #216
# 		Observational period #216 done!
# 		Uploading visit occurrence for group #216
# 		Visit occurrence #216 done!
# 		Uploading measurements for group #216
# 		Measurement #216 done!
# 		2905448 of 2907018 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #216
# 		Pharmaceuticals #216 done!
# 		48063 of 54727 (87.82%) drugs records translated
# 	Group #216 completed!
# 	Translating item 218 of 250
# 		Uploading observational period for group #217
# 		Observational period #217 done!
# 		Uploading visit occurrence for group #217
# 		Visit occurrence #217 done!
# 		Uploading measurements for group #217
# 		Measurement #217 done!
# 		3368114 of 3369753 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #217
# 		Pharmaceuticals #217 done!
# 		62074 of 70098 (88.55%) drugs records translated
# 	Group #217 completed!
# 	Translating item 219 of 250
# 		Uploading observational period for group #218
# 		Observational period #218 done!
# 		Uploading visit occurrence for group #218
# 		Visit occurrence #218 done!
# 		Uploading measurements for group #218
# 		Measurement #218 done!
# 		3039252 of 3040946 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #218
# 		Pharmaceuticals #218 done!
# 		62698 of 69310 (90.46%) drugs records translated
# 	Group #218 completed!
# 	Translating item 220 of 250
# 		Uploading observational period for group #219
# 		Observational period #219 done!
# 		Uploading visit occurrence for group #219
# 		Visit occurrence #219 done!
# 		Uploading measurements for group #219
# 		Measurement #219 done!
# 		2662934 of 2664302 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #219
# 		Pharmaceuticals #219 done!
# 		47477 of 54405 (87.27%) drugs records translated
# 	Group #219 completed!
# 	Translating item 221 of 250
# 		Uploading observational period for group #220
# 		Observational period #220 done!
# 		Uploading visit occurrence for group #220
# 		Visit occurrence #220 done!
# 		Uploading measurements for group #220
# 		Measurement #220 done!
# 		4077804 of 4079877 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #220
# 		Pharmaceuticals #220 done!
# 		74030 of 86362 (85.72%) drugs records translated
# 	Group #220 completed!
# 	Translating item 222 of 250
# 		Uploading observational period for group #221
# 		Observational period #221 done!
# 		Uploading visit occurrence for group #221
# 		Visit occurrence #221 done!
# 		Uploading measurements for group #221
# 		Measurement #221 done!
# 		2853486 of 2854977 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #221
# 		Pharmaceuticals #221 done!
# 		52007 of 62756 (82.87%) drugs records translated
# 	Group #221 completed!
# 	Translating item 223 of 250
# 		Uploading observational period for group #222
# 		Observational period #222 done!
# 		Uploading visit occurrence for group #222
# 		Visit occurrence #222 done!
# 		Uploading measurements for group #222
# 		Measurement #222 done!
# 		2147877 of 2149096 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #222
# 		Pharmaceuticals #222 done!
# 		44349 of 50050 (88.61%) drugs records translated
# 	Group #222 completed!
# 	Translating item 224 of 250
# 		Uploading observational period for group #223
# 		Observational period #223 done!
# 		Uploading visit occurrence for group #223
# 		Visit occurrence #223 done!
# 		Uploading measurements for group #223
# 		Measurement #223 done!
# 		2341369 of 2342533 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #223
# 		Pharmaceuticals #223 done!
# 		44920 of 50969 (88.13%) drugs records translated
# 	Group #223 completed!
# 	Translating item 225 of 250
# 		Uploading observational period for group #224
# 		Observational period #224 done!
# 		Uploading visit occurrence for group #224
# 		Visit occurrence #224 done!
# 		Uploading measurements for group #224
# 		Measurement #224 done!
# 		2142522 of 2143620 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #224
# 		Pharmaceuticals #224 done!
# 		35034 of 40886 (85.69%) drugs records translated
# 	Group #224 completed!
# 	Translating item 226 of 250
# 		Uploading observational period for group #225
# 		Observational period #225 done!
# 		Uploading visit occurrence for group #225
# 		Visit occurrence #225 done!
# 		Uploading measurements for group #225
# 		Measurement #225 done!
# 		2734797 of 2736151 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #225
# 		Pharmaceuticals #225 done!
# 		54678 of 63605 (85.96%) drugs records translated
# 	Group #225 completed!
# 	Translating item 227 of 250
# 		Uploading observational period for group #226
# 		Observational period #226 done!
# 		Uploading visit occurrence for group #226
# 		Visit occurrence #226 done!
# 		Uploading measurements for group #226
# 		Measurement #226 done!
# 		2286702 of 2287881 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #226
# 		Pharmaceuticals #226 done!
# 		43064 of 46800 (92.02%) drugs records translated
# 	Group #226 completed!
# 	Translating item 228 of 250
# 		Uploading observational period for group #227
# 		Observational period #227 done!
# 		Uploading visit occurrence for group #227
# 		Visit occurrence #227 done!
# 		Uploading measurements for group #227
# 		Measurement #227 done!
# 		2535336 of 2536684 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #227
# 		Pharmaceuticals #227 done!
# 		47576 of 53849 (88.35%) drugs records translated
# 	Group #227 completed!
# 	Translating item 229 of 250
# 		Uploading observational period for group #228
# 		Observational period #228 done!
# 		Uploading visit occurrence for group #228
# 		Visit occurrence #228 done!
# 		Uploading measurements for group #228
# 		Measurement #228 done!
# 		4314337 of 4316741 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #228
# 		Pharmaceuticals #228 done!
# 		76796 of 91590 (83.85%) drugs records translated
# 	Group #228 completed!
# 	Translating item 230 of 250
# 		Uploading observational period for group #229
# 		Observational period #229 done!
# 		Uploading visit occurrence for group #229
# 		Visit occurrence #229 done!
# 		Uploading measurements for group #229
# 		Measurement #229 done!
# 		2450854 of 2452157 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #229
# 		Pharmaceuticals #229 done!
# 		41518 of 45156 (91.94%) drugs records translated
# 	Group #229 completed!
# 	Translating item 231 of 250
# 		Uploading observational period for group #230
# 		Observational period #230 done!
# 		Uploading visit occurrence for group #230
# 		Visit occurrence #230 done!
# 		Uploading measurements for group #230
# 		Measurement #230 done!
# 		2518952 of 2520309 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #230
# 		Pharmaceuticals #230 done!
# 		48328 of 53227 (90.80%) drugs records translated
# 	Group #230 completed!
# 	Translating item 232 of 250
# 		Uploading observational period for group #231
# 		Observational period #231 done!
# 		Uploading visit occurrence for group #231
# 		Visit occurrence #231 done!
# 		Uploading measurements for group #231
# 		Measurement #231 done!
# 		3460089 of 3461864 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #231
# 		Pharmaceuticals #231 done!
# 		72664 of 80895 (89.83%) drugs records translated
# 	Group #231 completed!
# 	Translating item 233 of 250
# 		Uploading observational period for group #232
# 		Observational period #232 done!
# 		Uploading visit occurrence for group #232
# 		Visit occurrence #232 done!
# 		Uploading measurements for group #232
# 		Measurement #232 done!
# 		3012299 of 3013809 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #232
# 		Pharmaceuticals #232 done!
# 		56245 of 65675 (85.64%) drugs records translated
# 	Group #232 completed!
# 	Translating item 234 of 250
# 		Uploading observational period for group #233
# 		Observational period #233 done!
# 		Uploading visit occurrence for group #233
# 		Visit occurrence #233 done!
# 		Uploading measurements for group #233
# 		Measurement #233 done!
# 		4433628 of 4435893 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #233
# 		Pharmaceuticals #233 done!
# 		80370 of 92194 (87.17%) drugs records translated
# 	Group #233 completed!
# 	Translating item 235 of 250
# 		Uploading observational period for group #234
# 		Observational period #234 done!
# 		Uploading visit occurrence for group #234
# 		Visit occurrence #234 done!
# 		Uploading measurements for group #234
# 		Measurement #234 done!
# 		3813593 of 3815489 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #234
# 		Pharmaceuticals #234 done!
# 		67554 of 78834 (85.69%) drugs records translated
# 	Group #234 completed!
# 	Translating item 236 of 250
# 		Uploading observational period for group #235
# 		Observational period #235 done!
# 		Uploading visit occurrence for group #235
# 		Visit occurrence #235 done!
# 		Uploading measurements for group #235
# 		Measurement #235 done!
# 		2869823 of 2871369 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #235
# 		Pharmaceuticals #235 done!
# 		52546 of 57625 (91.19%) drugs records translated
# 	Group #235 completed!
# 	Translating item 237 of 250
# 		Uploading observational period for group #236
# 		Observational period #236 done!
# 		Uploading visit occurrence for group #236
# 		Visit occurrence #236 done!
# 		Uploading measurements for group #236
# 		Measurement #236 done!
# 		2935334 of 2937029 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #236
# 		Pharmaceuticals #236 done!
# 		57397 of 64543 (88.93%) drugs records translated
# 	Group #236 completed!
# 	Translating item 238 of 250
# 		Uploading observational period for group #237
# 		Observational period #237 done!
# 		Uploading visit occurrence for group #237
# 		Visit occurrence #237 done!
# 		Uploading measurements for group #237
# 		Measurement #237 done!
# 		3101738 of 3103172 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #237
# 		Pharmaceuticals #237 done!
# 		57007 of 64824 (87.94%) drugs records translated
# 	Group #237 completed!
# 	Translating item 239 of 250
# 		Uploading observational period for group #238
# 		Observational period #238 done!
# 		Uploading visit occurrence for group #238
# 		Visit occurrence #238 done!
# 		Uploading measurements for group #238
# 		Measurement #238 done!
# 		4272162 of 4274236 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #238
# 		Pharmaceuticals #238 done!
# 		76133 of 94282 (80.75%) drugs records translated
# 	Group #238 completed!
# 	Translating item 240 of 250
# 		Uploading observational period for group #239
# 		Observational period #239 done!
# 		Uploading visit occurrence for group #239
# 		Visit occurrence #239 done!
# 		Uploading measurements for group #239
# 		Measurement #239 done!
# 		3625716 of 3627575 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #239
# 		Pharmaceuticals #239 done!
# 		70648 of 81929 (86.23%) drugs records translated
# 	Group #239 completed!
# 	Translating item 241 of 250
# 		Uploading observational period for group #240
# 		Observational period #240 done!
# 		Uploading visit occurrence for group #240
# 		Visit occurrence #240 done!
# 		Uploading measurements for group #240
# 		Measurement #240 done!
# 		4555769 of 4557893 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #240
# 		Pharmaceuticals #240 done!
# 		72540 of 88433 (82.03%) drugs records translated
# 	Group #240 completed!
# 	Translating item 242 of 250
# 		Uploading observational period for group #241
# 		Observational period #241 done!
# 		Uploading visit occurrence for group #241
# 		Visit occurrence #241 done!
# 		Uploading measurements for group #241
# 		Measurement #241 done!
# 		2759377 of 2760689 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #241
# 		Pharmaceuticals #241 done!
# 		49441 of 57711 (85.67%) drugs records translated
# 	Group #241 completed!
# 	Translating item 243 of 250
# 		Uploading observational period for group #242
# 		Observational period #242 done!
# 		Uploading visit occurrence for group #242
# 		Visit occurrence #242 done!
# 		Uploading measurements for group #242
# 		Measurement #242 done!
# 		3246907 of 3248629 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #242
# 		Pharmaceuticals #242 done!
# 		63804 of 72908 (87.51%) drugs records translated
# 	Group #242 completed!
# 	Translating item 244 of 250
# 		Uploading observational period for group #243
# 		Observational period #243 done!
# 		Uploading visit occurrence for group #243
# 		Visit occurrence #243 done!
# 		Uploading measurements for group #243
# 		Measurement #243 done!
# 		2693208 of 2694570 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #243
# 		Pharmaceuticals #243 done!
# 		51887 of 57918 (89.59%) drugs records translated
# 	Group #243 completed!
# 	Translating item 245 of 250
# 		Uploading observational period for group #244
# 		Observational period #244 done!
# 		Uploading visit occurrence for group #244
# 		Visit occurrence #244 done!
# 		Uploading measurements for group #244
# 		Measurement #244 done!
# 		3667410 of 3669236 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #244
# 		Pharmaceuticals #244 done!
# 		66839 of 79907 (83.65%) drugs records translated
# 	Group #244 completed!
# 	Translating item 246 of 250
# 		Uploading observational period for group #245
# 		Observational period #245 done!
# 		Uploading visit occurrence for group #245
# 		Visit occurrence #245 done!
# 		Uploading measurements for group #245
# 		Measurement #245 done!
# 		2966894 of 2968448 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #245
# 		Pharmaceuticals #245 done!
# 		56693 of 62517 (90.68%) drugs records translated
# 	Group #245 completed!
# 	Translating item 247 of 250
# 		Uploading observational period for group #246
# 		Observational period #246 done!
# 		Uploading visit occurrence for group #246
# 		Visit occurrence #246 done!
# 		Uploading measurements for group #246
# 		Measurement #246 done!
# 		2929830 of 2931559 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #246
# 		Pharmaceuticals #246 done!
# 		53757 of 61467 (87.46%) drugs records translated
# 	Group #246 completed!
# 	Translating item 248 of 250
# 		Uploading observational period for group #247
# 		Observational period #247 done!
# 		Uploading visit occurrence for group #247
# 		Visit occurrence #247 done!
# 		Uploading measurements for group #247
# 		Measurement #247 done!
# 		2401571 of 2402783 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #247
# 		Pharmaceuticals #247 done!
# 		40557 of 45357 (89.42%) drugs records translated
# 	Group #247 completed!
# 	Translating item 249 of 250
# 		Uploading observational period for group #248
# 		Observational period #248 done!
# 		Uploading visit occurrence for group #248
# 		Visit occurrence #248 done!
# 		Uploading measurements for group #248
# 		Measurement #248 done!
# 		4185244 of 4187405 (99.95%) observations translated
# 		Uploading visit pharmaceuticals for group #248
# 		Pharmaceuticals #248 done!
# 		86348 of 98892 (87.32%) drugs records translated
# 	Group #248 completed!
# 	Translating item 250 of 250
# 		Uploading observational period for group #249
# 		Observational period #249 done!
# 		Uploading visit occurrence for group #249
# 		Visit occurrence #249 done!
# 		Uploading measurements for group #249
# 		Measurement #249 done!
# 		2634073 of 2635524 (99.94%) observations translated
# 		Uploading visit pharmaceuticals for group #249
# 		Pharmaceuticals #249 done!
# 		45712 of 51174 (89.33%) drugs records translated
# 	Group #249 completed!
# Full Translation completed!
# 		776525063 of 776921131 (99.95%) total observations translated
# 		14148308 of 16270399 (86.96%) drugs records translated
# 		790673371 of 793191530 (99.68%) all the records were translated
# Process ended at: 2020-08-13 20:59:24.858066

# %%
print(UploadDB_Optimized.__doc__)
# Out:
#     Functionality: In this class you can translate the whole hiRID into Postgresql, feel free to modify it according to your needs
#
#     Variables:
#
#     	*hirid_directory: Folder where your HiRID files uncompressed are located. Do not modify the file tree in order to work properly
#
#     	*postgres_add: Connection string for the postgres database
#
#     	*mapping_file: Directory path and file name for the Usagi's mapping folder, for more information about it check:
# https://www.ohdsi.org/web/wiki/doku.php?id=documentation:software:usagi
#
#     	*max_group: Default value 250. Given that HiRID is divided in 250 groups the max group is the number of groups you want to upload
#
#     	*sampling_mode: Allows the user to insert only a percentage of the data
#
#     Example:
#     	uploadDb=UploadDB_Optimized('D:\YourFolderGoesHere\',"dbname='dbname' user='user' host='localhost' password='password' connect_timeout=1",'D:\DirectoryPath\Vocabulary_translation.csv',1)
#
#     	uploadDb.translate_upload()
